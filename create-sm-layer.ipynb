# %% [markdown]
# ### Create a SageMaker Lambda layer

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/lambda-collection

# %%
# !python -V
# Out:
# Python 3.6.10 :: Anaconda, Inc.

# %%
# !pip install sagemaker -t ./sm_layer
# Out:
# Collecting sagemaker
#   Using cached sagemaker-2.50.0-py2.py3-none-any.whl
# Collecting smdebug-rulesconfig==1.0.1
#   Using cached smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Collecting boto3>=1.16.32
#   Using cached boto3-1.18.10-py3-none-any.whl (131 kB)
# Collecting botocore<1.22.0,>=1.21.10
#   Using cached botocore-1.21.10-py3-none-any.whl (7.8 MB)
# Collecting importlib-metadata>=1.4.0
#   Using cached importlib_metadata-4.6.1-py3-none-any.whl (17 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Using cached jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting numpy>=1.9.0
#   Using cached numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting packaging>=20.0
#   Using cached packaging-21.0-py3-none-any.whl (40 kB)
# Collecting protobuf>=3.1
#   Using cached protobuf-3.17.3-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting protobuf3-to-dict>=0.1.5
#   Using cached protobuf3_to_dict-0.1.5-py3-none-any.whl
# Collecting pyparsing>=2.0.2
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting python-dateutil<3.0.0,>=2.1
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Using cached s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Collecting six>=1.9
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting typing-extensions>=3.6.4
#   Using cached typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Using cached urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Collecting attrs
#   Using cached attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting google-pasta
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting pandas
#   Using cached pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting pytz>=2017.2
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting pathos
#   Using cached pathos-0.2.8-py2.py3-none-any.whl (81 kB)
# Collecting dill>=0.3.4
#   Using cached dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting multiprocess>=0.70.12
#   Using cached multiprocess-0.70.12.2-py36-none-any.whl (106 kB)
# Collecting pox>=0.3.0
#   Using cached pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Collecting ppft>=1.6.6.4
#   Using cached ppft-1.6.6.4-py3-none-any.whl (65 kB)
# Installing collected packages: six, urllib3, python-dateutil, jmespath, dill, botocore, zipp, typing-extensions, s3transfer, pytz, pyparsing, protobuf, ppft, pox, numpy, multiprocess, smdebug-rulesconfig, protobuf3-to-dict, pathos, pandas, packaging, importlib-metadata, google-pasta, boto3, attrs, sagemaker
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# awscli 1.18.223 requires botocore==1.19.63, but you have botocore 1.21.10 which is incompatible.
# awscli 1.18.223 requires s3transfer<0.4.0,>=0.3.0, but you have s3transfer 0.5.0 which is incompatible.
# Successfully installed attrs-21.2.0 boto3-1.18.10 botocore-1.21.10 dill-0.3.4 google-pasta-0.2.0 importlib-metadata-4.6.1 jmespath-0.10.0 multiprocess-0.70.12.2 numpy-1.19.5 packaging-21.0 pandas-1.1.5 pathos-0.2.8 pox-0.3.0 ppft-1.6.6.4 protobuf-3.17.3 protobuf3-to-dict-0.1.5 pyparsing-2.4.7 python-dateutil-2.8.2 pytz-2021.1 s3transfer-0.5.0 sagemaker-2.50.0 six-1.16.0 smdebug-rulesconfig-1.0.1 typing-extensions-3.10.0.0 urllib3-1.26.6 zipp-3.5.0
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/importlib_metadata-4.6.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/urllib3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/tests already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/dill already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/six-1.16.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pandas-1.1.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/sagemaker-2.50.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/boto3 already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/google_pasta-0.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pathos already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/numpy-1.19.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/multiprocess-0.70.12.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pyparsing-2.4.7.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/dateutil already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/protobuf-3.17.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/zipp.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/dill-0.3.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/numpy.libs already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/jmespath-0.10.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/urllib3-1.26.6.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/s3transfer already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pasta already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pp already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/attrs-21.2.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pox already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/zipp-3.5.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/botocore already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/attr already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/importlib_metadata already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/google already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/botocore-1.21.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/_multiprocess already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/python_dateutil-2.8.2.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pandas already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/numpy already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/__pycache__ already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/multiprocess already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/Misc already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/packaging already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pyparsing.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/protobuf-3.17.3-py3.6-nspkg.pth already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/smdebug_rulesconfig-1.0.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/sagemaker already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pox-0.3.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pathos-0.2.8.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/packaging-21.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/s3transfer-0.5.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pytz already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/ppft-1.6.6.4.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/protobuf_to_dict.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/ppft already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/smdebug_rulesconfig already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/protobuf3_to_dict-0.1.5.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/jmespath already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/boto3-1.18.10.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/typing_extensions.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/typing_extensions-3.10.0.0.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/pytz-2021.1.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/six.py already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /home/ec2-user/SageMaker/lambda-collection/sm_layer/bin already exists. Specify --upgrade to force replacement.
# WARNING: You are using pip version 20.3.3; however, version 21.2.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !zip -r sm_layer.zip sm_layer/
# Out:
# updating: sm_layer/ (stored 0%)
# updating: sm_layer/pox/ (stored 0%)
# updating: sm_layer/pox/_disk.py (deflated 59%)
# updating: sm_layer/pox/shutils.py (deflated 72%)
# updating: sm_layer/pox/info.py (deflated 56%)
# updating: sm_layer/pox/__init__.py (deflated 49%)
# updating: sm_layer/pox/utils.py (deflated 69%)
# updating: sm_layer/pox/__main__.py (deflated 52%)
# updating: sm_layer/pox/__pycache__/ (stored 0%)
# updating: sm_layer/pox/__pycache__/utils.cpython-36.pyc (deflated 57%)
# updating: sm_layer/pox/__pycache__/_disk.cpython-36.pyc (deflated 44%)
# updating: sm_layer/pox/__pycache__/shutils.cpython-36.pyc (deflated 54%)
# updating: sm_layer/pox/__pycache__/__main__.cpython-36.pyc (deflated 37%)
# updating: sm_layer/pox/__pycache__/__init__.cpython-36.pyc (deflated 34%)
# updating: sm_layer/pox/__pycache__/info.cpython-36.pyc (deflated 55%)
# updating: sm_layer/pox/tests/ (stored 0%)
# updating: sm_layer/pox/tests/test_utils.py (deflated 66%)
# updating: sm_layer/pox/tests/__init__.py (deflated 37%)
# updating: sm_layer/pox/tests/test_shutils.py (deflated 60%)
# updating: sm_layer/pox/tests/__main__.py (deflated 38%)
# updating: sm_layer/pox/tests/__pycache__/ (stored 0%)
# updating: sm_layer/pox/tests/__pycache__/test_utils.cpython-36.pyc (deflated 39%)
# updating: sm_layer/pox/tests/__pycache__/__main__.cpython-36.pyc (deflated 24%)
# updating: sm_layer/pox/tests/__pycache__/__init__.cpython-36.pyc (deflated 30%)
# updating: sm_layer/pox/tests/__pycache__/test_shutils.cpython-36.pyc (deflated 37%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/ (stored 0%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/WHEEL (stored 0%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/METADATA (deflated 65%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/LICENSE (deflated 35%)
# updating: sm_layer/importlib_metadata-4.6.1.dist-info/RECORD (deflated 56%)
# updating: sm_layer/s3transfer/ (stored 0%)
# updating: sm_layer/s3transfer/futures.py (deflated 74%)
# updating: sm_layer/s3transfer/tasks.py (deflated 72%)
# updating: sm_layer/s3transfer/download.py (deflated 77%)
# updating: sm_layer/s3transfer/__init__.py (deflated 74%)
# updating: sm_layer/s3transfer/compat.py (deflated 59%)
# updating: sm_layer/s3transfer/delete.py (deflated 63%)
# updating: sm_layer/s3transfer/utils.py (deflated 73%)
# updating: sm_layer/s3transfer/upload.py (deflated 78%)
# updating: sm_layer/s3transfer/subscribers.py (deflated 64%)
# updating: sm_layer/s3transfer/processpool.py (deflated 76%)
# updating: sm_layer/s3transfer/__pycache__/ (stored 0%)
# updating: sm_layer/s3transfer/__pycache__/delete.cpython-36.pyc (deflated 56%)
# updating: sm_layer/s3transfer/__pycache__/utils.cpython-36.pyc (deflated 61%)
# updating: sm_layer/s3transfer/__pycache__/constants.cpython-36.pyc (deflated 24%)
# updating: sm_layer/s3transfer/__pycache__/upload.cpython-36.pyc (deflated 66%)
# updating: sm_layer/s3transfer/__pycache__/processpool.cpython-36.pyc (deflated 65%)
# updating: sm_layer/s3transfer/__pycache__/bandwidth.cpython-36.pyc (deflated 66%)
# updating: sm_layer/s3transfer/__pycache__/compat.cpython-36.pyc (deflated 44%)
# updating: sm_layer/s3transfer/__pycache__/copies.cpython-36.pyc (deflated 58%)
# updating: sm_layer/s3transfer/__pycache__/subscribers.cpython-36.pyc (deflated 56%)
# updating: sm_layer/s3transfer/__pycache__/exceptions.cpython-36.pyc (deflated 51%)
# updating: sm_layer/s3transfer/__pycache__/tasks.cpython-36.pyc (deflated 60%)
# updating: sm_layer/s3transfer/__pycache__/crt.cpython-36.pyc (deflated 60%)
# updating: sm_layer/s3transfer/__pycache__/futures.cpython-36.pyc (deflated 65%)
# updating: sm_layer/s3transfer/__pycache__/__init__.cpython-36.pyc (deflated 59%)
# updating: sm_layer/s3transfer/__pycache__/manager.cpython-36.pyc (deflated 63%)
# updating: sm_layer/s3transfer/__pycache__/download.cpython-36.pyc (deflated 63%)
# updating: sm_layer/s3transfer/constants.py (deflated 40%)
# updating: sm_layer/s3transfer/manager.py (deflated 76%)
# updating: sm_layer/s3transfer/exceptions.py (deflated 48%)
# updating: sm_layer/s3transfer/crt.py (deflated 75%)
# updating: sm_layer/s3transfer/bandwidth.py (deflated 75%)
# updating: sm_layer/s3transfer/copies.py (deflated 77%)
# updating: sm_layer/packaging-21.0.dist-info/ (stored 0%)
# updating: sm_layer/packaging-21.0.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/packaging-21.0.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/packaging-21.0.dist-info/WHEEL (stored 0%)
# updating: sm_layer/packaging-21.0.dist-info/METADATA (deflated 66%)
# updating: sm_layer/packaging-21.0.dist-info/LICENSE.APACHE (deflated 65%)
# updating: sm_layer/packaging-21.0.dist-info/LICENSE.BSD (deflated 48%)
# updating: sm_layer/packaging-21.0.dist-info/LICENSE (deflated 36%)
# updating: sm_layer/packaging-21.0.dist-info/RECORD (deflated 53%)
# updating: sm_layer/multiprocess/ (stored 0%)
# updating: sm_layer/multiprocess/util.py (deflated 68%)
# updating: sm_layer/multiprocess/reduction.py (deflated 70%)
# updating: sm_layer/multiprocess/managers.py (deflated 76%)
# updating: sm_layer/multiprocess/spawn.py (deflated 67%)
# updating: sm_layer/multiprocess/queues.py (deflated 75%)
# updating: sm_layer/multiprocess/resource_sharer.py (deflated 71%)
# updating: sm_layer/multiprocess/connection.py (deflated 75%)
# updating: sm_layer/multiprocess/popen_fork.py (deflated 66%)
# updating: sm_layer/multiprocess/dummy/ (stored 0%)
# updating: sm_layer/multiprocess/dummy/connection.py (deflated 62%)
# updating: sm_layer/multiprocess/dummy/__init__.py (deflated 63%)
# updating: sm_layer/multiprocess/dummy/__pycache__/ (stored 0%)
# updating: sm_layer/multiprocess/dummy/__pycache__/connection.cpython-36.pyc (deflated 55%)
# updating: sm_layer/multiprocess/dummy/__pycache__/__init__.cpython-36.pyc (deflated 49%)
# updating: sm_layer/multiprocess/context.py (deflated 75%)
# updating: sm_layer/multiprocess/__init__.py (deflated 45%)
# updating: sm_layer/multiprocess/forkserver.py (deflated 69%)
# updating: sm_layer/multiprocess/process.py (deflated 69%)
# updating: sm_layer/multiprocess/popen_spawn_win32.py (deflated 63%)
# updating: sm_layer/multiprocess/semaphore_tracker.py (deflated 66%)
# updating: sm_layer/multiprocess/heap.py (deflated 69%)
# updating: sm_layer/multiprocess/pool.py (deflated 77%)
# updating: sm_layer/multiprocess/popen_forkserver.py (deflated 60%)
# updating: sm_layer/multiprocess/synchronize.py (deflated 77%)
# updating: sm_layer/multiprocess/__pycache__/ (stored 0%)
# updating: sm_layer/multiprocess/__pycache__/pool.cpython-36.pyc (deflated 57%)
# updating: sm_layer/multiprocess/__pycache__/spawn.cpython-36.pyc (deflated 46%)
# updating: sm_layer/multiprocess/__pycache__/heap.cpython-36.pyc (deflated 49%)
# updating: sm_layer/multiprocess/__pycache__/synchronize.cpython-36.pyc (deflated 60%)
# updating: sm_layer/multiprocess/__pycache__/queues.cpython-36.pyc (deflated 54%)
# updating: sm_layer/multiprocess/__pycache__/popen_spawn_posix.cpython-36.pyc (deflated 43%)
# updating: sm_layer/multiprocess/__pycache__/popen_fork.cpython-36.pyc (deflated 42%)
# updating: sm_layer/multiprocess/__pycache__/managers.cpython-36.pyc (deflated 58%)
# updating: sm_layer/multiprocess/__pycache__/forkserver.cpython-36.pyc (deflated 45%)
# updating: sm_layer/multiprocess/__pycache__/context.cpython-36.pyc (deflated 63%)
# updating: sm_layer/multiprocess/__pycache__/semaphore_tracker.cpython-36.pyc (deflated 44%)
# updating: sm_layer/multiprocess/__pycache__/popen_forkserver.cpython-36.pyc (deflated 42%)
# updating: sm_layer/multiprocess/__pycache__/util.cpython-36.pyc (deflated 50%)
# updating: sm_layer/multiprocess/__pycache__/popen_spawn_win32.cpython-36.pyc (deflated 40%)
# updating: sm_layer/multiprocess/__pycache__/process.cpython-36.pyc (deflated 52%)
# updating: sm_layer/multiprocess/__pycache__/reduction.cpython-36.pyc (deflated 49%)
# updating: sm_layer/multiprocess/__pycache__/sharedctypes.cpython-36.pyc (deflated 54%)
# updating: sm_layer/multiprocess/__pycache__/connection.cpython-36.pyc (deflated 55%)
# updating: sm_layer/multiprocess/__pycache__/__init__.cpython-36.pyc (deflated 24%)
# updating: sm_layer/multiprocess/__pycache__/resource_sharer.cpython-36.pyc (deflated 51%)
# updating: sm_layer/multiprocess/sharedctypes.py (deflated 72%)
# updating: sm_layer/multiprocess/tests/ (stored 0%)
# updating: sm_layer/multiprocess/tests/mp_preload.py (deflated 43%)
# updating: sm_layer/multiprocess/tests/test_multiprocessing_fork.py (deflated 47%)
# updating: sm_layer/multiprocess/tests/test_multiprocessing_spawn.py (deflated 37%)
# updating: sm_layer/multiprocess/tests/test_multiprocessing_main_handling.py (deflated 77%)
# updating: sm_layer/multiprocess/tests/mp_fork_bomb.py (deflated 38%)
# updating: sm_layer/multiprocess/tests/__init__.py (deflated 79%)
# updating: sm_layer/multiprocess/tests/test_multiprocessing_forkserver.py (deflated 43%)
# updating: sm_layer/multiprocess/tests/__main__.py (deflated 43%)
# updating: sm_layer/multiprocess/tests/__pycache__/ (stored 0%)
# updating: sm_layer/multiprocess/tests/__pycache__/test_multiprocessing_main_handling.cpython-36.pyc (deflated 61%)
# updating: sm_layer/multiprocess/tests/__pycache__/test_multiprocessing_forkserver.cpython-36.pyc (deflated 29%)
# updating: sm_layer/multiprocess/tests/__pycache__/mp_fork_bomb.cpython-36.pyc (deflated 30%)
# updating: sm_layer/multiprocess/tests/__pycache__/mp_preload.cpython-36.pyc (deflated 34%)
# updating: sm_layer/multiprocess/tests/__pycache__/test_multiprocessing_spawn.cpython-36.pyc (deflated 26%)
# updating: sm_layer/multiprocess/tests/__pycache__/test_multiprocessing_fork.cpython-36.pyc (deflated 28%)
# updating: sm_layer/multiprocess/tests/__pycache__/__main__.cpython-36.pyc (deflated 28%)
# updating: sm_layer/multiprocess/tests/__pycache__/__init__.cpython-36.pyc (deflated 63%)
# updating: sm_layer/multiprocess/popen_spawn_posix.py (deflated 65%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/ (stored 0%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/WHEEL (stored 0%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/METADATA (deflated 60%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/LICENSE (deflated 65%)
# updating: sm_layer/google_pasta-0.2.0.dist-info/RECORD (deflated 60%)
# updating: sm_layer/attr/ (stored 0%)
# updating: sm_layer/attr/_make.py (deflated 74%)
# updating: sm_layer/attr/_version_info.py (deflated 64%)
# updating: sm_layer/attr/_next_gen.py (deflated 66%)
# updating: sm_layer/attr/_config.py (deflated 54%)
# updating: sm_layer/attr/converters.pyi (deflated 54%)
# updating: sm_layer/attr/validators.pyi (deflated 69%)
# updating: sm_layer/attr/__init__.pyi (deflated 80%)
# updating: sm_layer/attr/validators.py (deflated 77%)
# updating: sm_layer/attr/filters.pyi (deflated 47%)
# updating: sm_layer/attr/_cmp.pyi (deflated 55%)
# updating: sm_layer/attr/converters.py (deflated 67%)
# updating: sm_layer/attr/_version_info.pyi (deflated 56%)
# updating: sm_layer/attr/_cmp.py (deflated 67%)
# updating: sm_layer/attr/__init__.py (deflated 58%)
# updating: sm_layer/attr/_funcs.py (deflated 77%)
# updating: sm_layer/attr/setters.pyi (deflated 52%)
# updating: sm_layer/attr/setters.py (deflated 63%)
# updating: sm_layer/attr/py.typed (stored 0%)
# updating: sm_layer/attr/exceptions.pyi (deflated 58%)
# updating: sm_layer/attr/__pycache__/ (stored 0%)
# updating: sm_layer/attr/__pycache__/validators.cpython-36.pyc (deflated 65%)
# updating: sm_layer/attr/__pycache__/setters.cpython-36.pyc (deflated 44%)
# updating: sm_layer/attr/__pycache__/converters.cpython-36.pyc (deflated 49%)
# updating: sm_layer/attr/__pycache__/exceptions.cpython-36.pyc (deflated 60%)
# updating: sm_layer/attr/__pycache__/_compat.cpython-36.pyc (deflated 55%)
# updating: sm_layer/attr/__pycache__/_cmp.cpython-36.pyc (deflated 50%)
# updating: sm_layer/attr/__pycache__/_make.cpython-36.pyc (deflated 61%)
# updating: sm_layer/attr/__pycache__/_funcs.cpython-36.pyc (deflated 59%)
# updating: sm_layer/attr/__pycache__/_next_gen.cpython-36.pyc (deflated 47%)
# updating: sm_layer/attr/__pycache__/__init__.cpython-36.pyc (deflated 35%)
# updating: sm_layer/attr/__pycache__/_config.cpython-36.pyc (deflated 36%)
# updating: sm_layer/attr/__pycache__/filters.cpython-36.pyc (deflated 50%)
# updating: sm_layer/attr/__pycache__/_version_info.cpython-36.pyc (deflated 47%)
# updating: sm_layer/attr/exceptions.py (deflated 65%)
# updating: sm_layer/attr/_compat.py (deflated 70%)
# updating: sm_layer/attr/filters.py (deflated 63%)
# updating: sm_layer/protobuf-3.17.3-py3.6-nspkg.pth (deflated 49%)
# updating: sm_layer/importlib_metadata/ (stored 0%)
# updating: sm_layer/importlib_metadata/_itertools.py (deflated 56%)
# updating: sm_layer/importlib_metadata/_functools.py (deflated 59%)
# updating: sm_layer/importlib_metadata/__init__.py (deflated 73%)
# updating: sm_layer/importlib_metadata/_adapters.py (deflated 60%)
# updating: sm_layer/importlib_metadata/py.typed (stored 0%)
# updating: sm_layer/importlib_metadata/_meta.py (deflated 61%)
# updating: sm_layer/importlib_metadata/_collections.py (deflated 48%)
# updating: sm_layer/importlib_metadata/_text.py (deflated 65%)
# updating: sm_layer/importlib_metadata/__pycache__/ (stored 0%)
# updating: sm_layer/importlib_metadata/__pycache__/_meta.cpython-36.pyc (deflated 55%)
# updating: sm_layer/importlib_metadata/__pycache__/_functools.cpython-36.pyc (deflated 52%)
# updating: sm_layer/importlib_metadata/__pycache__/_itertools.cpython-36.pyc (deflated 28%)
# updating: sm_layer/importlib_metadata/__pycache__/_compat.cpython-36.pyc (deflated 44%)
# updating: sm_layer/importlib_metadata/__pycache__/_adapters.cpython-36.pyc (deflated 43%)
# updating: sm_layer/importlib_metadata/__pycache__/_text.cpython-36.pyc (deflated 57%)
# updating: sm_layer/importlib_metadata/__pycache__/__init__.cpython-36.pyc (deflated 63%)
# updating: sm_layer/importlib_metadata/__pycache__/_collections.cpython-36.pyc (deflated 45%)
# updating: sm_layer/importlib_metadata/_compat.py (deflated 56%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/ (stored 0%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/WHEEL (deflated 14%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/METADATA (deflated 58%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/LICENSE (deflated 42%)
# updating: sm_layer/pyparsing-2.4.7.dist-info/RECORD (deflated 38%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/ (stored 0%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/WHEEL (deflated 14%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/LICENSE.txt (deflated 65%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/METADATA (deflated 68%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/REQUESTED (stored 0%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/entry_points.txt (deflated 18%)
# updating: sm_layer/sagemaker-2.50.0.dist-info/RECORD (deflated 64%)
# updating: sm_layer/pandas-1.1.5.dist-info/ (stored 0%)
# updating: sm_layer/pandas-1.1.5.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/pandas-1.1.5.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/pandas-1.1.5.dist-info/WHEEL (deflated 3%)
# updating: sm_layer/pandas-1.1.5.dist-info/METADATA (deflated 55%)
# updating: sm_layer/pandas-1.1.5.dist-info/AUTHORS.md (deflated 58%)
# updating: sm_layer/pandas-1.1.5.dist-info/entry_points.txt (deflated 28%)
# updating: sm_layer/pandas-1.1.5.dist-info/LICENSE (deflated 48%)
# updating: sm_layer/pandas-1.1.5.dist-info/RECORD (deflated 69%)
# updating: sm_layer/botocore-1.21.10.dist-info/ (stored 0%)
# updating: sm_layer/botocore-1.21.10.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/botocore-1.21.10.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/botocore-1.21.10.dist-info/NOTICE (deflated 60%)
# updating: sm_layer/botocore-1.21.10.dist-info/WHEEL (stored 0%)
# updating: sm_layer/botocore-1.21.10.dist-info/LICENSE.txt (deflated 65%)
# updating: sm_layer/botocore-1.21.10.dist-info/METADATA (deflated 60%)
# updating: sm_layer/botocore-1.21.10.dist-info/RECORD (deflated 66%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/ (stored 0%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/WHEEL (stored 0%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/METADATA (deflated 60%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/metadata.json (deflated 55%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/DESCRIPTION.rst (deflated 58%)
# updating: sm_layer/ppft-1.6.6.4.dist-info/RECORD (deflated 62%)
# updating: sm_layer/pasta/ (stored 0%)
# updating: sm_layer/pasta/base/ (stored 0%)
# updating: sm_layer/pasta/base/codegen_test.py (deflated 58%)
# updating: sm_layer/pasta/base/ast_utils_test.py (deflated 65%)
# updating: sm_layer/pasta/base/formatting.py (deflated 52%)
# updating: sm_layer/pasta/base/scope_test.py (deflated 83%)
# updating: sm_layer/pasta/base/annotate.py (deflated 79%)
# updating: sm_layer/pasta/base/fstring_utils.py (deflated 47%)
# updating: sm_layer/pasta/base/codegen.py (deflated 64%)
# updating: sm_layer/pasta/base/test_utils.py (deflated 58%)
# updating: sm_layer/pasta/base/__init__.py (stored 0%)
# updating: sm_layer/pasta/base/test_utils_test.py (deflated 54%)
# updating: sm_layer/pasta/base/ast_utils.py (deflated 61%)
# updating: sm_layer/pasta/base/scope.py (deflated 72%)
# updating: sm_layer/pasta/base/__pycache__/ (stored 0%)
# updating: sm_layer/pasta/base/__pycache__/formatting.cpython-36.pyc (deflated 44%)
# updating: sm_layer/pasta/base/__pycache__/codegen.cpython-36.pyc (deflated 53%)
# updating: sm_layer/pasta/base/__pycache__/token_generator.cpython-36.pyc (deflated 54%)
# updating: sm_layer/pasta/base/__pycache__/scope_test.cpython-36.pyc (deflated 68%)
# updating: sm_layer/pasta/base/__pycache__/annotate.cpython-36.pyc (deflated 64%)
# updating: sm_layer/pasta/base/__pycache__/test_utils.cpython-36.pyc (deflated 39%)
# updating: sm_layer/pasta/base/__pycache__/annotate_test.cpython-36.pyc (deflated 60%)
# updating: sm_layer/pasta/base/__pycache__/scope.cpython-36.pyc (deflated 57%)
# updating: sm_layer/pasta/base/__pycache__/test_utils_test.cpython-36.pyc (deflated 53%)
# updating: sm_layer/pasta/base/__pycache__/ast_utils.cpython-36.pyc (deflated 45%)
# updating: sm_layer/pasta/base/__pycache__/ast_utils_test.cpython-36.pyc (deflated 52%)
# updating: sm_layer/pasta/base/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: sm_layer/pasta/base/__pycache__/fstring_utils.cpython-36.pyc (deflated 40%)
# updating: sm_layer/pasta/base/__pycache__/codegen_test.cpython-36.pyc (deflated 47%)
# updating: sm_layer/pasta/base/__pycache__/ast_constants.cpython-36.pyc (deflated 38%)
# updating: sm_layer/pasta/base/annotate_test.py (deflated 74%)
# updating: sm_layer/pasta/base/ast_constants.py (deflated 62%)
# updating: sm_layer/pasta/base/token_generator.py (deflated 70%)
# updating: sm_layer/pasta/augment/ (stored 0%)
# updating: sm_layer/pasta/augment/inline_test.py (deflated 64%)
# updating: sm_layer/pasta/augment/inline.py (deflated 56%)
# updating: sm_layer/pasta/augment/__init__.py (stored 0%)
# updating: sm_layer/pasta/augment/errors.py (deflated 40%)
# updating: sm_layer/pasta/augment/rename.py (deflated 64%)
# updating: sm_layer/pasta/augment/import_utils.py (deflated 65%)
# updating: sm_layer/pasta/augment/import_utils_test.py (deflated 82%)
# updating: sm_layer/pasta/augment/rename_test.py (deflated 77%)
# updating: sm_layer/pasta/augment/__pycache__/ (stored 0%)
# updating: sm_layer/pasta/augment/__pycache__/inline.cpython-36.pyc (deflated 36%)
# updating: sm_layer/pasta/augment/__pycache__/rename_test.cpython-36.pyc (deflated 70%)
# updating: sm_layer/pasta/augment/__pycache__/errors.cpython-36.pyc (deflated 29%)
# updating: sm_layer/pasta/augment/__pycache__/import_utils_test.cpython-36.pyc (deflated 75%)
# updating: sm_layer/pasta/augment/__pycache__/import_utils.cpython-36.pyc (deflated 50%)
# updating: sm_layer/pasta/augment/__pycache__/rename.cpython-36.pyc (deflated 47%)
# updating: sm_layer/pasta/augment/__pycache__/inline_test.cpython-36.pyc (deflated 58%)
# updating: sm_layer/pasta/augment/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: sm_layer/pasta/__init__.py (deflated 43%)
# updating: sm_layer/pasta/__pycache__/ (stored 0%)
# updating: sm_layer/pasta/__pycache__/__init__.cpython-36.pyc (deflated 34%)
# updating: sm_layer/protobuf-3.17.3.dist-info/ (stored 0%)
# updating: sm_layer/protobuf-3.17.3.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/protobuf-3.17.3.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/protobuf-3.17.3.dist-info/WHEEL (deflated 22%)
# updating: sm_layer/protobuf-3.17.3.dist-info/METADATA (deflated 63%)
# updating: sm_layer/protobuf-3.17.3.dist-info/namespace_packages.txt (stored 0%)
# updating: sm_layer/protobuf-3.17.3.dist-info/RECORD (deflated 65%)
# updating: sm_layer/_multiprocess/ (stored 0%)
# updating: sm_layer/_multiprocess/__init__.py (stored 0%)
# updating: sm_layer/_multiprocess/__pycache__/ (stored 0%)
# updating: sm_layer/_multiprocess/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: sm_layer/pathos/ (stored 0%)
# updating: sm_layer/pathos/profile.py (deflated 73%)
# updating: sm_layer/pathos/serial.py (deflated 65%)
# updating: sm_layer/pathos/util.py (deflated 64%)
# updating: sm_layer/pathos/portpicker.py (deflated 60%)
# updating: sm_layer/pathos/helpers/ (stored 0%)
# updating: sm_layer/pathos/helpers/pp_helper.py (deflated 73%)
# updating: sm_layer/pathos/helpers/__init__.py (deflated 63%)
# updating: sm_layer/pathos/helpers/__pycache__/ (stored 0%)
# updating: sm_layer/pathos/helpers/__pycache__/mp_helper.cpython-36.pyc (deflated 38%)
# updating: sm_layer/pathos/helpers/__pycache__/pp_helper.cpython-36.pyc (deflated 57%)
# updating: sm_layer/pathos/helpers/__pycache__/__init__.cpython-36.pyc (deflated 44%)
# updating: sm_layer/pathos/helpers/mp_helper.py (deflated 57%)
# updating: sm_layer/pathos/info.py (deflated 62%)
# updating: sm_layer/pathos/pp.py (deflated 38%)
# updating: sm_layer/pathos/threading.py (deflated 72%)
# updating: sm_layer/pathos/connection.py (deflated 65%)
# updating: sm_layer/pathos/pools.py (deflated 52%)
# updating: sm_layer/pathos/abstract_launcher.py (deflated 72%)
# updating: sm_layer/pathos/server.py (deflated 59%)
# updating: sm_layer/pathos/selector.py (deflated 70%)
# updating: sm_layer/pathos/parallel.py (deflated 71%)
# updating: sm_layer/pathos/__init__.py (deflated 56%)
# updating: sm_layer/pathos/python.py (deflated 36%)
# updating: sm_layer/pathos/hosts.py (deflated 52%)
# updating: sm_layer/pathos/pp_map.py (deflated 59%)
# updating: sm_layer/pathos/xmlrpc/ (stored 0%)
# updating: sm_layer/pathos/xmlrpc/server.py (deflated 67%)
# updating: sm_layer/pathos/xmlrpc/__init__.py (deflated 13%)
# updating: sm_layer/pathos/xmlrpc/__pycache__/ (stored 0%)
# updating: sm_layer/pathos/xmlrpc/__pycache__/server.cpython-36.pyc (deflated 52%)
# updating: sm_layer/pathos/xmlrpc/__pycache__/__init__.cpython-36.pyc (deflated 15%)
# updating: sm_layer/pathos/mp_map.py (deflated 64%)
# updating: sm_layer/pathos/__main__.py (deflated 68%)
# updating: sm_layer/pathos/__pycache__/ (stored 0%)
# updating: sm_layer/pathos/__pycache__/server.cpython-36.pyc (deflated 46%)
# updating: sm_layer/pathos/__pycache__/hosts.cpython-36.pyc (deflated 43%)
# updating: sm_layer/pathos/__pycache__/pp_map.cpython-36.pyc (deflated 45%)
# updating: sm_layer/pathos/__pycache__/pools.cpython-36.pyc (deflated 35%)
# updating: sm_layer/pathos/__pycache__/threading.cpython-36.pyc (deflated 59%)
# updating: sm_layer/pathos/__pycache__/selector.cpython-36.pyc (deflated 53%)
# updating: sm_layer/pathos/__pycache__/mp_map.cpython-36.pyc (deflated 45%)
# updating: sm_layer/pathos/__pycache__/multiprocessing.cpython-36.pyc (deflated 59%)
# updating: sm_layer/pathos/__pycache__/_ppserver_config.cpython-36.pyc (deflated 23%)
# updating: sm_layer/pathos/__pycache__/abstract_launcher.cpython-36.pyc (deflated 64%)
# updating: sm_layer/pathos/__pycache__/util.cpython-36.pyc (deflated 49%)
# updating: sm_layer/pathos/__pycache__/__main__.cpython-36.pyc (deflated 56%)
# updating: sm_layer/pathos/__pycache__/pp.cpython-36.pyc (deflated 27%)
# updating: sm_layer/pathos/__pycache__/parallel.cpython-36.pyc (deflated 57%)
# updating: sm_layer/pathos/__pycache__/serial.cpython-36.pyc (deflated 51%)
# updating: sm_layer/pathos/__pycache__/connection.cpython-36.pyc (deflated 50%)
# updating: sm_layer/pathos/__pycache__/profile.cpython-36.pyc (deflated 66%)
# updating: sm_layer/pathos/__pycache__/core.cpython-36.pyc (deflated 55%)
# updating: sm_layer/pathos/__pycache__/__init__.cpython-36.pyc (deflated 41%)
# updating: sm_layer/pathos/__pycache__/python.cpython-36.pyc (deflated 25%)
# updating: sm_layer/pathos/__pycache__/info.cpython-36.pyc (deflated 62%)
# updating: sm_layer/pathos/__pycache__/portpicker.cpython-36.pyc (deflated 47%)
# updating: sm_layer/pathos/core.py (deflated 67%)
# updating: sm_layer/pathos/tests/ (stored 0%)
# updating: sm_layer/pathos/tests/test_star.py (deflated 72%)
# updating: sm_layer/pathos/tests/test_join.py (deflated 80%)
# updating: sm_layer/pathos/tests/test_map.py (deflated 61%)
# updating: sm_layer/pathos/tests/test_with.py (deflated 55%)
# updating: sm_layer/pathos/tests/__init__.py (deflated 37%)
# updating: sm_layer/pathos/tests/test_pp.py (deflated 46%)
# updating: sm_layer/pathos/tests/test_decorate.py (deflated 59%)
# updating: sm_layer/pathos/tests/test_mp.py (deflated 52%)
# updating: sm_layer/pathos/tests/__main__.py (deflated 40%)
# updating: sm_layer/pathos/tests/__pycache__/ (stored 0%)
# updating: sm_layer/pathos/tests/__pycache__/test_mp.cpython-36.pyc (deflated 37%)
# updating: sm_layer/pathos/tests/__pycache__/test_pp.cpython-36.pyc (deflated 42%)
# updating: sm_layer/pathos/tests/__pycache__/__main__.cpython-36.pyc (deflated 24%)
# updating: sm_layer/pathos/tests/__pycache__/test_with.cpython-36.pyc (deflated 47%)
# updating: sm_layer/pathos/tests/__pycache__/test_join.cpython-36.pyc (deflated 58%)
# updating: sm_layer/pathos/tests/__pycache__/test_map.cpython-36.pyc (deflated 49%)
# updating: sm_layer/pathos/tests/__pycache__/test_star.cpython-36.pyc (deflated 53%)
# updating: sm_layer/pathos/tests/__pycache__/__init__.cpython-36.pyc (deflated 32%)
# updating: sm_layer/pathos/tests/__pycache__/test_decorate.cpython-36.pyc (deflated 54%)
# updating: sm_layer/pathos/secure/ (stored 0%)
# updating: sm_layer/pathos/secure/copier.py (deflated 65%)
# updating: sm_layer/pathos/secure/connection.py (deflated 65%)
# updating: sm_layer/pathos/secure/__init__.py (deflated 36%)
# updating: sm_layer/pathos/secure/tunnel.py (deflated 63%)
# updating: sm_layer/pathos/secure/__pycache__/ (stored 0%)
# updating: sm_layer/pathos/secure/__pycache__/copier.cpython-36.pyc (deflated 54%)
# updating: sm_layer/pathos/secure/__pycache__/connection.cpython-36.pyc (deflated 51%)
# updating: sm_layer/pathos/secure/__pycache__/__init__.cpython-36.pyc (deflated 21%)
# updating: sm_layer/pathos/secure/__pycache__/tunnel.cpython-36.pyc (deflated 46%)
# updating: sm_layer/pathos/_ppserver_config.py (deflated 32%)
# updating: sm_layer/pathos/multiprocessing.py (deflated 72%)
# updating: sm_layer/six.py (deflated 76%)
# updating: sm_layer/bin/ (stored 0%)
# updating: sm_layer/bin/pox (deflated 41%)
# updating: sm_layer/bin/sagemaker-upgrade-v2 (deflated 27%)
# updating: sm_layer/bin/f2py3.6 (deflated 27%)
# updating: sm_layer/bin/ppserver (deflated 68%)
# updating: sm_layer/bin/portpicker (deflated 29%)
# updating: sm_layer/bin/get_objgraph (deflated 50%)
# updating: sm_layer/bin/pathos_connect (deflated 67%)
# updating: sm_layer/bin/f2py3 (deflated 27%)
# updating: sm_layer/bin/__pycache__/ (stored 0%)
# updating: sm_layer/bin/__pycache__/jp.cpython-36.pyc (deflated 39%)
# updating: sm_layer/bin/f2py (deflated 27%)
# updating: sm_layer/bin/undill (deflated 33%)
# updating: sm_layer/bin/jp.py (deflated 64%)
# updating: sm_layer/sagemaker/ (stored 0%)
# updating: sm_layer/sagemaker/inputs.py (deflated 70%)
# updating: sm_layer/sagemaker/model_monitor/ (stored 0%)
# updating: sm_layer/sagemaker/model_monitor/model_monitoring.py (deflated 85%)
# updating: sm_layer/sagemaker/model_monitor/clarify_model_monitoring.py (deflated 86%)
# updating: sm_layer/sagemaker/model_monitor/dataset_format.py (deflated 62%)
# updating: sm_layer/sagemaker/model_monitor/__init__.py (deflated 69%)
# updating: sm_layer/sagemaker/model_monitor/monitoring_files.py (deflated 87%)
# updating: sm_layer/sagemaker/model_monitor/data_capture_config.py (deflated 65%)
# updating: sm_layer/sagemaker/model_monitor/cron_expression_generator.py (deflated 66%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/monitoring_files.cpython-36.pyc (deflated 79%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/clarify_model_monitoring.cpython-36.pyc (deflated 74%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/cron_expression_generator.cpython-36.pyc (deflated 62%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/data_capture_config.cpython-36.pyc (deflated 51%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/dataset_format.cpython-36.pyc (deflated 57%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/__init__.cpython-36.pyc (deflated 48%)
# updating: sm_layer/sagemaker/model_monitor/__pycache__/model_monitoring.cpython-36.pyc (deflated 76%)
# updating: sm_layer/sagemaker/algorithm.py (deflated 74%)
# updating: sm_layer/sagemaker/git_utils.py (deflated 76%)
# updating: sm_layer/sagemaker/huggingface/ (stored 0%)
# updating: sm_layer/sagemaker/huggingface/__init__.py (deflated 42%)
# updating: sm_layer/sagemaker/huggingface/model.py (deflated 72%)
# updating: sm_layer/sagemaker/huggingface/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/huggingface/__pycache__/estimator.cpython-36.pyc (deflated 63%)
# updating: sm_layer/sagemaker/huggingface/__pycache__/model.cpython-36.pyc (deflated 62%)
# updating: sm_layer/sagemaker/huggingface/__pycache__/__init__.cpython-36.pyc (deflated 29%)
# updating: sm_layer/sagemaker/huggingface/estimator.py (deflated 73%)
# updating: sm_layer/sagemaker/vpc_utils.py (deflated 68%)
# updating: sm_layer/sagemaker/chainer/ (stored 0%)
# updating: sm_layer/sagemaker/chainer/defaults.py (deflated 36%)
# updating: sm_layer/sagemaker/chainer/__init__.py (deflated 41%)
# updating: sm_layer/sagemaker/chainer/model.py (deflated 67%)
# updating: sm_layer/sagemaker/chainer/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/chainer/__pycache__/estimator.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/chainer/__pycache__/defaults.cpython-36.pyc (deflated 9%)
# updating: sm_layer/sagemaker/chainer/__pycache__/model.cpython-36.pyc (deflated 56%)
# updating: sm_layer/sagemaker/chainer/__pycache__/__init__.cpython-36.pyc (deflated 27%)
# updating: sm_layer/sagemaker/chainer/estimator.py (deflated 70%)
# updating: sm_layer/sagemaker/job.py (deflated 77%)
# updating: sm_layer/sagemaker/image_uri_config/ (stored 0%)
# updating: sm_layer/sagemaker/image_uri_config/lda.json (deflated 64%)
# updating: sm_layer/sagemaker/image_uri_config/vw.json (deflated 74%)
# updating: sm_layer/sagemaker/image_uri_config/linear-learner.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/blazingtext.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/randomcutforest.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/spark.json (deflated 80%)
# updating: sm_layer/sagemaker/image_uri_config/ray-tensorflow.json (deflated 93%)
# updating: sm_layer/sagemaker/image_uri_config/ray-pytorch.json (deflated 73%)
# updating: sm_layer/sagemaker/image_uri_config/kmeans.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/debugger.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/object2vec.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/tensorflow.json (deflated 98%)
# updating: sm_layer/sagemaker/image_uri_config/forecasting-deepar.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/sparkml-serving.json (deflated 82%)
# updating: sm_layer/sagemaker/image_uri_config/inferentia-mxnet.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/data-wrangler.json (deflated 63%)
# updating: sm_layer/sagemaker/image_uri_config/coach-tensorflow.json (deflated 93%)
# updating: sm_layer/sagemaker/image_uri_config/neo-tensorflow.json (deflated 70%)
# updating: sm_layer/sagemaker/image_uri_config/image-classification-neo.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/coach-mxnet.json (deflated 86%)
# updating: sm_layer/sagemaker/image_uri_config/sklearn.json (deflated 82%)
# updating: sm_layer/sagemaker/image_uri_config/xgboost.json (deflated 91%)
# updating: sm_layer/sagemaker/image_uri_config/ipinsights.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/image-classification.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/neo-pytorch.json (deflated 87%)
# updating: sm_layer/sagemaker/image_uri_config/pytorch.json (deflated 97%)
# updating: sm_layer/sagemaker/image_uri_config/knn.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/inferentia-tensorflow.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/seq2seq.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/chainer.json (deflated 90%)
# updating: sm_layer/sagemaker/image_uri_config/object-detection.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/inferentia-pytorch.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/mxnet.json (deflated 97%)
# updating: sm_layer/sagemaker/image_uri_config/ntm.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/huggingface.json (deflated 96%)
# updating: sm_layer/sagemaker/image_uri_config/pca.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/xgboost-neo.json (deflated 67%)
# updating: sm_layer/sagemaker/image_uri_config/model-monitor.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/neo-mxnet.json (deflated 69%)
# updating: sm_layer/sagemaker/image_uri_config/clarify.json (deflated 69%)
# updating: sm_layer/sagemaker/image_uri_config/semantic-segmentation.json (deflated 66%)
# updating: sm_layer/sagemaker/image_uri_config/factorization-machines.json (deflated 66%)
# updating: sm_layer/sagemaker/spark/ (stored 0%)
# updating: sm_layer/sagemaker/spark/processing.py (deflated 83%)
# updating: sm_layer/sagemaker/spark/defaults.py (deflated 37%)
# updating: sm_layer/sagemaker/spark/__init__.py (deflated 38%)
# updating: sm_layer/sagemaker/spark/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/spark/__pycache__/processing.cpython-36.pyc (deflated 73%)
# updating: sm_layer/sagemaker/spark/__pycache__/defaults.cpython-36.pyc (deflated 14%)
# updating: sm_layer/sagemaker/spark/__pycache__/__init__.cpython-36.pyc (deflated 20%)
# updating: sm_layer/sagemaker/transformer.py (deflated 76%)
# updating: sm_layer/sagemaker/_studio.py (deflated 62%)
# updating: sm_layer/sagemaker/dataset_definition/ (stored 0%)
# updating: sm_layer/sagemaker/dataset_definition/inputs.py (deflated 68%)
# updating: sm_layer/sagemaker/dataset_definition/__init__.py (deflated 42%)
# updating: sm_layer/sagemaker/dataset_definition/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/dataset_definition/__pycache__/inputs.cpython-36.pyc (deflated 65%)
# updating: sm_layer/sagemaker/dataset_definition/__pycache__/__init__.cpython-36.pyc (deflated 32%)
# updating: sm_layer/sagemaker/wrangler/ (stored 0%)
# updating: sm_layer/sagemaker/wrangler/processing.py (deflated 67%)
# updating: sm_layer/sagemaker/wrangler/__init__.py (stored 0%)
# updating: sm_layer/sagemaker/wrangler/ingestion.py (deflated 79%)
# updating: sm_layer/sagemaker/wrangler/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/wrangler/__pycache__/processing.cpython-36.pyc (deflated 58%)
# updating: sm_layer/sagemaker/wrangler/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: sm_layer/sagemaker/wrangler/__pycache__/ingestion.cpython-36.pyc (deflated 64%)
# updating: sm_layer/sagemaker/s3.py (deflated 74%)
# updating: sm_layer/sagemaker/feature_store/ (stored 0%)
# updating: sm_layer/sagemaker/feature_store/inputs.py (deflated 73%)
# updating: sm_layer/sagemaker/feature_store/feature_definition.py (deflated 71%)
# updating: sm_layer/sagemaker/feature_store/feature_group.py (deflated 75%)
# updating: sm_layer/sagemaker/feature_store/__init__.py (deflated 37%)
# updating: sm_layer/sagemaker/feature_store/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/feature_store/__pycache__/feature_group.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/feature_store/__pycache__/feature_definition.cpython-36.pyc (deflated 66%)
# updating: sm_layer/sagemaker/feature_store/__pycache__/inputs.cpython-36.pyc (deflated 65%)
# updating: sm_layer/sagemaker/feature_store/__pycache__/__init__.cpython-36.pyc (deflated 17%)
# updating: sm_layer/sagemaker/processing.py (deflated 82%)
# updating: sm_layer/sagemaker/parameter.py (deflated 72%)
# updating: sm_layer/sagemaker/content_types.py (deflated 43%)
# updating: sm_layer/sagemaker/clarify.py (deflated 81%)
# updating: sm_layer/sagemaker/lineage/ (stored 0%)
# updating: sm_layer/sagemaker/lineage/visualizer.py (deflated 77%)
# updating: sm_layer/sagemaker/lineage/artifact.py (deflated 75%)
# updating: sm_layer/sagemaker/lineage/_utils.py (deflated 58%)
# updating: sm_layer/sagemaker/lineage/association.py (deflated 73%)
# updating: sm_layer/sagemaker/lineage/context.py (deflated 75%)
# updating: sm_layer/sagemaker/lineage/__init__.py (deflated 38%)
# updating: sm_layer/sagemaker/lineage/_api_types.py (deflated 80%)
# updating: sm_layer/sagemaker/lineage/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/lineage/__pycache__/visualizer.cpython-36.pyc (deflated 65%)
# updating: sm_layer/sagemaker/lineage/__pycache__/_api_types.cpython-36.pyc (deflated 74%)
# updating: sm_layer/sagemaker/lineage/__pycache__/association.cpython-36.pyc (deflated 63%)
# updating: sm_layer/sagemaker/lineage/__pycache__/_utils.cpython-36.pyc (deflated 42%)
# updating: sm_layer/sagemaker/lineage/__pycache__/context.cpython-36.pyc (deflated 63%)
# updating: sm_layer/sagemaker/lineage/__pycache__/artifact.cpython-36.pyc (deflated 61%)
# updating: sm_layer/sagemaker/lineage/__pycache__/__init__.cpython-36.pyc (deflated 13%)
# updating: sm_layer/sagemaker/lineage/__pycache__/action.cpython-36.pyc (deflated 63%)
# updating: sm_layer/sagemaker/lineage/action.py (deflated 74%)
# updating: sm_layer/sagemaker/deserializers.py (deflated 79%)
# updating: sm_layer/sagemaker/local/ (stored 0%)
# updating: sm_layer/sagemaker/local/image.py (deflated 75%)
# updating: sm_layer/sagemaker/local/__init__.py (deflated 40%)
# updating: sm_layer/sagemaker/local/data.py (deflated 74%)
# updating: sm_layer/sagemaker/local/utils.py (deflated 61%)
# updating: sm_layer/sagemaker/local/entities.py (deflated 76%)
# updating: sm_layer/sagemaker/local/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/local/__pycache__/utils.cpython-36.pyc (deflated 51%)
# updating: sm_layer/sagemaker/local/__pycache__/entities.cpython-36.pyc (deflated 56%)
# updating: sm_layer/sagemaker/local/__pycache__/image.cpython-36.pyc (deflated 57%)
# updating: sm_layer/sagemaker/local/__pycache__/local_session.cpython-36.pyc (deflated 64%)
# updating: sm_layer/sagemaker/local/__pycache__/data.cpython-36.pyc (deflated 65%)
# updating: sm_layer/sagemaker/local/__pycache__/__init__.cpython-36.pyc (deflated 25%)
# updating: sm_layer/sagemaker/local/local_session.py (deflated 77%)
# updating: sm_layer/sagemaker/automl/ (stored 0%)
# updating: sm_layer/sagemaker/automl/automl.py (deflated 78%)
# updating: sm_layer/sagemaker/automl/__init__.py (deflated 37%)
# updating: sm_layer/sagemaker/automl/candidate_estimator.py (deflated 76%)
# updating: sm_layer/sagemaker/automl/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/automl/__pycache__/automl.cpython-36.pyc (deflated 64%)
# updating: sm_layer/sagemaker/automl/__pycache__/candidate_estimator.cpython-36.pyc (deflated 58%)
# updating: sm_layer/sagemaker/automl/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: sm_layer/sagemaker/__init__.py (deflated 67%)
# updating: sm_layer/sagemaker/workflow/ (stored 0%)
# updating: sm_layer/sagemaker/workflow/properties.py (deflated 67%)
# updating: sm_layer/sagemaker/workflow/_repack_model.py (deflated 59%)
# updating: sm_layer/sagemaker/workflow/callback_step.py (deflated 65%)
# updating: sm_layer/sagemaker/workflow/execution_variables.py (deflated 54%)
# updating: sm_layer/sagemaker/workflow/airflow.py (deflated 81%)
# updating: sm_layer/sagemaker/workflow/condition_step.py (deflated 67%)
# updating: sm_layer/sagemaker/workflow/utilities.py (deflated 52%)
# updating: sm_layer/sagemaker/workflow/_utils.py (deflated 76%)
# updating: sm_layer/sagemaker/workflow/__init__.py (deflated 37%)
# updating: sm_layer/sagemaker/workflow/pipeline_experiment_config.py (deflated 64%)
# updating: sm_layer/sagemaker/workflow/entities.py (deflated 55%)
# updating: sm_layer/sagemaker/workflow/steps.py (deflated 79%)
# updating: sm_layer/sagemaker/workflow/conditions.py (deflated 79%)
# updating: sm_layer/sagemaker/workflow/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/workflow/__pycache__/callback_step.cpython-36.pyc (deflated 52%)
# updating: sm_layer/sagemaker/workflow/__pycache__/pipeline_experiment_config.cpython-36.pyc (deflated 55%)
# updating: sm_layer/sagemaker/workflow/__pycache__/airflow.cpython-36.pyc (deflated 71%)
# updating: sm_layer/sagemaker/workflow/__pycache__/steps.cpython-36.pyc (deflated 69%)
# updating: sm_layer/sagemaker/workflow/__pycache__/parameters.cpython-36.pyc (deflated 62%)
# updating: sm_layer/sagemaker/workflow/__pycache__/conditions.cpython-36.pyc (deflated 71%)
# updating: sm_layer/sagemaker/workflow/__pycache__/entities.cpython-36.pyc (deflated 47%)
# updating: sm_layer/sagemaker/workflow/__pycache__/pipeline.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/workflow/__pycache__/condition_step.cpython-36.pyc (deflated 54%)
# updating: sm_layer/sagemaker/workflow/__pycache__/_utils.cpython-36.pyc (deflated 62%)
# updating: sm_layer/sagemaker/workflow/__pycache__/functions.cpython-36.pyc (deflated 36%)
# updating: sm_layer/sagemaker/workflow/__pycache__/utilities.cpython-36.pyc (deflated 37%)
# updating: sm_layer/sagemaker/workflow/__pycache__/_repack_model.cpython-36.pyc (deflated 34%)
# updating: sm_layer/sagemaker/workflow/__pycache__/step_collections.cpython-36.pyc (deflated 58%)
# updating: sm_layer/sagemaker/workflow/__pycache__/execution_variables.cpython-36.pyc (deflated 46%)
# updating: sm_layer/sagemaker/workflow/__pycache__/__init__.cpython-36.pyc (deflated 17%)
# updating: sm_layer/sagemaker/workflow/__pycache__/properties.cpython-36.pyc (deflated 53%)
# updating: sm_layer/sagemaker/workflow/functions.py (deflated 48%)
# updating: sm_layer/sagemaker/workflow/pipeline.py (deflated 75%)
# updating: sm_layer/sagemaker/workflow/parameters.py (deflated 71%)
# updating: sm_layer/sagemaker/workflow/step_collections.py (deflated 75%)
# updating: sm_layer/sagemaker/deprecations.py (deflated 69%)
# updating: sm_layer/sagemaker/multidatamodel.py (deflated 72%)
# updating: sm_layer/sagemaker/amazon/ (stored 0%)
# updating: sm_layer/sagemaker/amazon/object2vec.py (deflated 74%)
# updating: sm_layer/sagemaker/amazon/knn.py (deflated 71%)
# updating: sm_layer/sagemaker/amazon/ipinsights.py (deflated 70%)
# updating: sm_layer/sagemaker/amazon/pca.py (deflated 69%)
# updating: sm_layer/sagemaker/amazon/amazon_estimator.py (deflated 71%)
# updating: sm_layer/sagemaker/amazon/validation.py (deflated 64%)
# updating: sm_layer/sagemaker/amazon/hyperparameter.py (deflated 64%)
# updating: sm_layer/sagemaker/amazon/__init__.py (deflated 37%)
# updating: sm_layer/sagemaker/amazon/randomcutforest.py (deflated 68%)
# updating: sm_layer/sagemaker/amazon/kmeans.py (deflated 69%)
# updating: sm_layer/sagemaker/amazon/factorization_machines.py (deflated 75%)
# updating: sm_layer/sagemaker/amazon/ntm.py (deflated 69%)
# updating: sm_layer/sagemaker/amazon/lda.py (deflated 69%)
# updating: sm_layer/sagemaker/amazon/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/amazon/__pycache__/object2vec.cpython-36.pyc (deflated 62%)
# updating: sm_layer/sagemaker/amazon/__pycache__/linear_learner.cpython-36.pyc (deflated 65%)
# updating: sm_layer/sagemaker/amazon/__pycache__/amazon_estimator.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/amazon/__pycache__/randomcutforest.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/amazon/__pycache__/hyperparameter.cpython-36.pyc (deflated 52%)
# updating: sm_layer/sagemaker/amazon/__pycache__/kmeans.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/amazon/__pycache__/record_pb2.cpython-36.pyc (deflated 68%)
# updating: sm_layer/sagemaker/amazon/__pycache__/knn.cpython-36.pyc (deflated 62%)
# updating: sm_layer/sagemaker/amazon/__pycache__/lda.cpython-36.pyc (deflated 61%)
# updating: sm_layer/sagemaker/amazon/__pycache__/ipinsights.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/amazon/__pycache__/validation.cpython-36.pyc (deflated 68%)
# updating: sm_layer/sagemaker/amazon/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: sm_layer/sagemaker/amazon/__pycache__/factorization_machines.cpython-36.pyc (deflated 67%)
# updating: sm_layer/sagemaker/amazon/__pycache__/ntm.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/amazon/__pycache__/common.cpython-36.pyc (deflated 55%)
# updating: sm_layer/sagemaker/amazon/__pycache__/pca.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/amazon/linear_learner.py (deflated 74%)
# updating: sm_layer/sagemaker/amazon/common.py (deflated 73%)
# updating: sm_layer/sagemaker/amazon/record_pb2.py (deflated 90%)
# updating: sm_layer/sagemaker/utils.py (deflated 70%)
# updating: sm_layer/sagemaker/rl/ (stored 0%)
# updating: sm_layer/sagemaker/rl/__init__.py (deflated 38%)
# updating: sm_layer/sagemaker/rl/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/rl/__pycache__/estimator.cpython-36.pyc (deflated 59%)
# updating: sm_layer/sagemaker/rl/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: sm_layer/sagemaker/rl/estimator.py (deflated 72%)
# updating: sm_layer/sagemaker/predictor.py (deflated 76%)
# updating: sm_layer/sagemaker/session.py (deflated 83%)
# updating: sm_layer/sagemaker/xgboost/ (stored 0%)
# updating: sm_layer/sagemaker/xgboost/defaults.py (deflated 42%)
# updating: sm_layer/sagemaker/xgboost/__init__.py (deflated 43%)
# updating: sm_layer/sagemaker/xgboost/utils.py (deflated 48%)
# updating: sm_layer/sagemaker/xgboost/model.py (deflated 66%)
# updating: sm_layer/sagemaker/xgboost/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/xgboost/__pycache__/utils.cpython-36.pyc (deflated 35%)
# updating: sm_layer/sagemaker/xgboost/__pycache__/estimator.cpython-36.pyc (deflated 60%)
# updating: sm_layer/sagemaker/xgboost/__pycache__/defaults.cpython-36.pyc (deflated 28%)
# updating: sm_layer/sagemaker/xgboost/__pycache__/model.cpython-36.pyc (deflated 56%)
# updating: sm_layer/sagemaker/xgboost/__pycache__/__init__.cpython-36.pyc (deflated 28%)
# updating: sm_layer/sagemaker/xgboost/estimator.py (deflated 69%)
# updating: sm_layer/sagemaker/sklearn/ (stored 0%)
# updating: sm_layer/sagemaker/sklearn/processing.py (deflated 63%)
# updating: sm_layer/sagemaker/sklearn/defaults.py (deflated 37%)
# updating: sm_layer/sagemaker/sklearn/__init__.py (deflated 44%)
# updating: sm_layer/sagemaker/sklearn/model.py (deflated 67%)
# updating: sm_layer/sagemaker/sklearn/__pycache__/ (stored 0%)
# updating: sm_layer/sagemaker/sklearn/__pycache__/processing.cpython-36.pyc (deflated 54%)
# updating: sm_layer/sagemaker/sklearn/__pycache__/estimator.cpython-36.pyc (deflated 59%)
# updating: sm_layer/sagemaker/sklearn/__pycache__/defaults.cpython-36.pyc (deflated 12%)
# updating: sm_layer/sagemaker/sklearn/__pycache__/model.cpython-36.pyc (deflated 57%)
# updating: sm_layer/sagemaker/sklearn/__pycache__/__init__.cpython-36.pyc (deflated 31%)
# updating: sm_layer/sagemaker/sklearn/estimator.py (deflated 70%)
# updating: sm_layer/sagemaker/debugger/ (stored 0%)
# ...
# updating: sm_layer/numpy/doc/__pycache__/structured_arrays.cpython-36.pyc (deflated 68%)
# updating: sm_layer/numpy/doc/constants.py (deflated 79%)
# updating: sm_layer/numpy/doc/misc.py (deflated 57%)
# updating: sm_layer/numpy/setup.py (deflated 65%)
# updating: sm_layer/numpy/ma/ (stored 0%)
# updating: sm_layer/numpy/ma/testutils.py (deflated 76%)
# updating: sm_layer/numpy/ma/extras.py (deflated 76%)
# updating: sm_layer/numpy/ma/timer_comparison.py (deflated 78%)
# updating: sm_layer/numpy/ma/mrecords.py (deflated 73%)
# updating: sm_layer/numpy/ma/__init__.py (deflated 50%)
# updating: sm_layer/numpy/ma/bench.py (deflated 76%)
# updating: sm_layer/numpy/ma/__pycache__/ (stored 0%)
# updating: sm_layer/numpy/ma/__pycache__/timer_comparison.cpython-36.pyc (deflated 56%)
# updating: sm_layer/numpy/ma/__pycache__/testutils.cpython-36.pyc (deflated 56%)
# updating: sm_layer/numpy/ma/__pycache__/setup.cpython-36.pyc (deflated 30%)
# updating: sm_layer/numpy/ma/__pycache__/bench.cpython-36.pyc (deflated 50%)
# updating: sm_layer/numpy/ma/__pycache__/core.cpython-36.pyc (deflated 69%)
# updating: sm_layer/numpy/ma/__pycache__/mrecords.cpython-36.pyc (deflated 58%)
# updating: sm_layer/numpy/ma/__pycache__/__init__.cpython-36.pyc (deflated 43%)
# updating: sm_layer/numpy/ma/__pycache__/extras.cpython-36.pyc (deflated 65%)
# updating: sm_layer/numpy/ma/core.py (deflated 78%)
# updating: sm_layer/numpy/ma/tests/ (stored 0%)
# updating: sm_layer/numpy/ma/tests/test_deprecations.py (deflated 70%)
# updating: sm_layer/numpy/ma/tests/test_core.py (deflated 82%)
# updating: sm_layer/numpy/ma/tests/test_extras.py (deflated 84%)
# updating: sm_layer/numpy/ma/tests/__init__.py (stored 0%)
# updating: sm_layer/numpy/ma/tests/test_subclassing.py (deflated 74%)
# updating: sm_layer/numpy/ma/tests/test_mrecords.py (deflated 80%)
# updating: sm_layer/numpy/ma/tests/test_old_ma.py (deflated 78%)
# updating: sm_layer/numpy/ma/tests/__pycache__/ (stored 0%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_subclassing.cpython-36.pyc (deflated 59%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_extras.cpython-36.pyc (deflated 68%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_regression.cpython-36.pyc (deflated 58%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_mrecords.cpython-36.pyc (deflated 59%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_core.cpython-36.pyc (deflated 68%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_deprecations.cpython-36.pyc (deflated 56%)
# updating: sm_layer/numpy/ma/tests/__pycache__/__init__.cpython-36.pyc (deflated 19%)
# updating: sm_layer/numpy/ma/tests/__pycache__/test_old_ma.cpython-36.pyc (deflated 61%)
# updating: sm_layer/numpy/ma/tests/test_regression.py (deflated 65%)
# updating: sm_layer/numpy/ma/setup.py (deflated 46%)
# updating: sm_layer/numpy/version.py (deflated 30%)
# updating: sm_layer/numpy/polynomial/ (stored 0%)
# updating: sm_layer/numpy/polynomial/hermite_e.py (deflated 75%)
# updating: sm_layer/numpy/polynomial/laguerre.py (deflated 75%)
# updating: sm_layer/numpy/polynomial/chebyshev.py (deflated 75%)
# updating: sm_layer/numpy/polynomial/__init__.py (deflated 49%)
# updating: sm_layer/numpy/polynomial/_polybase.py (deflated 77%)
# updating: sm_layer/numpy/polynomial/__pycache__/ (stored 0%)
# updating: sm_layer/numpy/polynomial/__pycache__/hermite_e.cpython-36.pyc (deflated 70%)
# updating: sm_layer/numpy/polynomial/__pycache__/polynomial.cpython-36.pyc (deflated 70%)
# updating: sm_layer/numpy/polynomial/__pycache__/legendre.cpython-36.pyc (deflated 70%)
# updating: sm_layer/numpy/polynomial/__pycache__/setup.cpython-36.pyc (deflated 31%)
# updating: sm_layer/numpy/polynomial/__pycache__/_polybase.cpython-36.pyc (deflated 69%)
# updating: sm_layer/numpy/polynomial/__pycache__/polyutils.cpython-36.pyc (deflated 60%)
# updating: sm_layer/numpy/polynomial/__pycache__/laguerre.cpython-36.pyc (deflated 70%)
# updating: sm_layer/numpy/polynomial/__pycache__/__init__.cpython-36.pyc (deflated 40%)
# updating: sm_layer/numpy/polynomial/__pycache__/chebyshev.cpython-36.pyc (deflated 70%)
# updating: sm_layer/numpy/polynomial/__pycache__/hermite.cpython-36.pyc (deflated 70%)
# updating: sm_layer/numpy/polynomial/polyutils.py (deflated 69%)
# updating: sm_layer/numpy/polynomial/tests/ (stored 0%)
# updating: sm_layer/numpy/polynomial/tests/test_printing.py (deflated 79%)
# updating: sm_layer/numpy/polynomial/tests/test_chebyshev.py (deflated 82%)
# updating: sm_layer/numpy/polynomial/tests/test_legendre.py (deflated 81%)
# updating: sm_layer/numpy/polynomial/tests/test_hermite.py (deflated 82%)
# updating: sm_layer/numpy/polynomial/tests/__init__.py (stored 0%)
# updating: sm_layer/numpy/polynomial/tests/test_classes.py (deflated 82%)
# updating: sm_layer/numpy/polynomial/tests/test_polynomial.py (deflated 82%)
# updating: sm_layer/numpy/polynomial/tests/test_laguerre.py (deflated 82%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/ (stored 0%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_chebyshev.cpython-36.pyc (deflated 66%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_legendre.cpython-36.pyc (deflated 64%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_polyutils.cpython-36.pyc (deflated 55%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_printing.cpython-36.pyc (deflated 71%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_hermite.cpython-36.pyc (deflated 64%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_polynomial.cpython-36.pyc (deflated 64%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_classes.cpython-36.pyc (deflated 64%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_laguerre.cpython-36.pyc (deflated 64%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/test_hermite_e.cpython-36.pyc (deflated 65%)
# updating: sm_layer/numpy/polynomial/tests/__pycache__/__init__.cpython-36.pyc (deflated 18%)
# updating: sm_layer/numpy/polynomial/tests/test_hermite_e.py (deflated 82%)
# updating: sm_layer/numpy/polynomial/tests/test_polyutils.py (deflated 75%)
# updating: sm_layer/numpy/polynomial/polynomial.py (deflated 75%)
# updating: sm_layer/numpy/polynomial/setup.py (deflated 47%)
# updating: sm_layer/numpy/polynomial/hermite.py (deflated 75%)
# updating: sm_layer/numpy/polynomial/legendre.py (deflated 75%)
# updating: sm_layer/numpy/conftest.py (deflated 63%)
# updating: sm_layer/Misc/ (stored 0%)
# updating: sm_layer/Misc/NEWS.d/ (stored 0%)
# updating: sm_layer/Misc/NEWS.d/next/ (stored 0%)
# updating: sm_layer/Misc/NEWS.d/next/Library/ (stored 0%)
# updating: sm_layer/Misc/NEWS.d/next/Library/2021-05-14-16-06-02.bpo-44095.v_pLwY.rst (deflated 39%)
# updating: sm_layer/packaging/ (stored 0%)
# updating: sm_layer/packaging/tags.py (deflated 71%)
# updating: sm_layer/packaging/_structures.py (deflated 78%)
# updating: sm_layer/packaging/_musllinux.py (deflated 58%)
# updating: sm_layer/packaging/requirements.py (deflated 62%)
# updating: sm_layer/packaging/__init__.py (deflated 51%)
# updating: sm_layer/packaging/utils.py (deflated 65%)
# updating: sm_layer/packaging/py.typed (stored 0%)
# updating: sm_layer/packaging/__about__.py (deflated 46%)
# updating: sm_layer/packaging/_manylinux.py (deflated 68%)
# updating: sm_layer/packaging/__pycache__/ (stored 0%)
# updating: sm_layer/packaging/__pycache__/specifiers.cpython-36.pyc (deflated 64%)
# updating: sm_layer/packaging/__pycache__/_structures.cpython-36.pyc (deflated 72%)
# updating: sm_layer/packaging/__pycache__/utils.cpython-36.pyc (deflated 45%)
# updating: sm_layer/packaging/__pycache__/markers.cpython-36.pyc (deflated 55%)
# updating: sm_layer/packaging/__pycache__/version.cpython-36.pyc (deflated 62%)
# updating: sm_layer/packaging/__pycache__/_manylinux.cpython-36.pyc (deflated 48%)
# updating: sm_layer/packaging/__pycache__/_musllinux.cpython-36.pyc (deflated 41%)
# updating: sm_layer/packaging/__pycache__/tags.cpython-36.pyc (deflated 52%)
# updating: sm_layer/packaging/__pycache__/requirements.cpython-36.pyc (deflated 41%)
# updating: sm_layer/packaging/__pycache__/__init__.cpython-36.pyc (deflated 32%)
# updating: sm_layer/packaging/__pycache__/__about__.cpython-36.pyc (deflated 27%)
# updating: sm_layer/packaging/markers.py (deflated 68%)
# updating: sm_layer/packaging/specifiers.py (deflated 78%)
# updating: sm_layer/packaging/version.py (deflated 72%)
# updating: sm_layer/pyodbc.cpython-36m-x86_64-linux-gnu.so (deflated 65%)
# updating: sm_layer/pyodbc.pyi (deflated 71%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/ (stored 0%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/top_level.txt (stored 0%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/INSTALLER (stored 0%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/WHEEL (deflated 3%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/LICENSE.txt (deflated 39%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/METADATA (deflated 59%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/REQUESTED (stored 0%)
# updating: sm_layer/pyodbc-4.0.31.dist-info/RECORD (deflated 38%)
#   adding: sm_layer/var/ (stored 0%)
#   adding: sm_layer/var/cache/ (stored 0%)
#   adding: sm_layer/var/cache/yum/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/7a285f574b0b95abe00f3fbf306cd19920e33dbc1b734fa00fab2d3d5e888a79ca2e01bfdb24800e91fd771ac955da309fb5d72744a0d7485f80d5345d6ef726-primary.xml.gz (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/repomd.xml (deflated 63%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/packages/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/gen/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/gen/primary.xml (deflated 91%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/gen/primary.xml.sqlite (deflated 84%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-container-runtime/cachecookie (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/02b1320edfe2e5db2ef838a6397e50ac891ad1e515771c58e1de92e2ca634253-primary.sqlite.bz2 (deflated 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/repomd.xml (deflated 71%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/packages/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/gen/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/gen/primary_db.sqlite (deflated 94%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/cachecookie (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/439b29d841fc3c47b842f6357ea0805819ea0f39d762fb54d1c4478d92d6b5b51839a1c43fc82186ad5ee3832d3a75052f2b0b8d4aae8e962b8ae0a4097000d5-primary.xml.gz (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/repomd.xml (deflated 63%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/packages/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/gen/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/gen/primary.xml (deflated 89%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/gen/primary.xml.sqlite (deflated 87%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/nvidia-docker/cachecookie (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/primary.sqlite.bz2 (deflated 2%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/mirrorlist.txt (deflated 1%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/repomd.xml (deflated 67%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/packages/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/gen/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/gen/primary_db.sqlite (deflated 67%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-main/cachecookie (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/5ff67ac86ca77fc372d76149769950217fa0a96d08100761463161be8a9d60f41e31e562ec6c67fbf02177d1db55ee4a2b46560ca1813a3d225040c632cee924-primary.xml.gz (deflated 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/repomd.xml (deflated 62%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/packages/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/gen/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/gen/primary.xml (deflated 92%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/gen/primary.xml.sqlite (deflated 82%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/libnvidia-container/cachecookie (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/primary.sqlite.bz2 (deflated 3%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/mirrorlist.txt (deflated 4%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/repomd.xml (deflated 70%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/packages/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/gen/ (stored 0%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/gen/primary_db.sqlite (deflated 73%)
#   adding: sm_layer/var/cache/yum/x86_64/latest/amzn-updates/cachecookie (stored 0%)
#   adding: sm_layer/var/log/ (stored 0%)
#   adding: sm_layer/var/log/yum.log
# zip warning: Permission denied
# 	zip warning: could not open for reading: sm_layer/var/log/yum.log
#   adding: sm_layer/var/lib/ (stored 0%)
#   adding: sm_layer/var/lib/yum/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/nvidia-container-runtime/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/copr:copr.fedorainfracloud.org:vbatts:shadow-utils-newxidmap/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/nvidia-docker/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/amzn-main/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/libnvidia-container/ (stored 0%)
#   adding: sm_layer/var/lib/yum/repos/x86_64/latest/amzn-updates/ (stored 0%)
#   adding: sm_layer/var/lib/yum/yumdb/ (stored 0%)
#   adding: sm_layer/var/lib/rpm/ (stored 0%)
#   adding: sm_layer/var/lib/rpm/Requirename (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Sigmd5 (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Installtid (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Basenames (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Name (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Packages (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Sha1header (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Obsoletename (deflated 99%)
#   adding: sm_layer/var/lib/rpm/.dbenv.lock (stored 0%)
#   adding: sm_layer/var/lib/rpm/Dirnames (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Group (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Triggername (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Conflictname (deflated 99%)
#   adding: sm_layer/var/lib/rpm/Providename (deflated 99%)
#
# zip warning: Not all files were readable
#   files/entries read:  7161 (217M bytes)  skipped:  1 (0 bytes)

# %% [markdown]
# **Note:** Make sure you use same Python runtime all throughout the process.

# %% [markdown]
# ### Lambda Handler code

# %% [markdown]
# Use the zip created above to create a Lambda layer and use it when creating the Lambda handler.

# %%
import logging
import boto3
import json
import os


if os.getenv('AWS_EXECUTION_ENV') == 'AWS_Lambda_python3.6':
    import sys

    sys.path.insert(0, '/opt/sm_layer')

import sagemaker


print(f'Using SageMaker version: {sagemaker.__version__}')
print(f'Using Boto3 version: {boto3.__version__}')


def lambda_handler(event, context):
    body = {
        "message": "Hello World!",
        "input": event
    }
    response = {
        "statusCode": 200,
        "body": json.dumps(body)
    }
    return response
